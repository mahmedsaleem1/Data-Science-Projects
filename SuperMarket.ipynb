# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('supermarket_sales - Sheet1.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.drop('Invoice ID', axis=1, inplace=True)

# %%
data.shape
# Out:
# (1000, 16)

# %%
data.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
val = ['Unit price', 'Quantity', 'Total', 'cogs', 'gross margin percentage', 'gross income']

plt.figure(figsize=(2, 2))

for i in val:
    sns.displot(data=data[i])
    plt.title(f'Distribution of {i}', fontsize=16)
    plt.xlabel(i, fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
data['Month'] = data['Date'].dt.month

# %%
data.drop('Date',axis=1,inplace=True)

# %%
data['Time'] = pd.to_datetime(data['Time'])
data['Hour'] = data['Time'].dt.hour
data.drop('Time',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'Month', 'Hour'],
#       dtype='object')

# %% [markdown]
# # Data Visualization and Analysis

# %% [markdown]
# #### How do sales vary across different branches and cities?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Branch', y='Total', hue='City', data=data)
plt.title('Sales Variation Across Branches and Cities',color='red')
plt.xlabel('Branch',color='blue')
plt.ylabel('Total Sales',color='blue')
plt.legend(title='City')
plt.show()

# %% [markdown]
# ##### Observation : Order of sales(Branch 'C' --> Branch 'B' --> Branch 'A')

# %% [markdown]
# #### What is the distribution of customer types across different branches or cities?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Branch', hue='Customer type', data=data)
plt.title('Distribution of Customer Types Across Branches',color='red')
plt.xlabel('Branch',color='blue')
plt.ylabel('Count',color='blue')
plt.legend(title='Customer Type')
plt.show()

# %% [markdown]
# ##### Observation :
# #####    Branch 'A' --> More Normal Customers than Members.
# #####    Branch 'B' --> More Members than Normal Customers.
# #####    Branch 'C' --> Members and Normal Customer were almost equal but a bit more Normal Customers.

# %% [markdown]
# #### How does the unit price of products vary across different product lines?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Product line', y='Unit price', data=data)
plt.title('Unit Price Variation Across Product Lines',color='red')
plt.xlabel('Product Line',color='blue')
plt.ylabel('Unit Price',color='blue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Are there any peak times for sales during the day or specific days of the week?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Hour', y='Total', data=data)
plt.title('Hourly Sales Variation',color='red')
plt.xlabel('Hour of the Day',color='blue')
plt.ylabel('Total Sales',color='blue')
plt.show()

# %% [markdown]
# #### Are there any peak times for sales during the day or specific days of the week?

# %%
data['Month'] = data['Month'].astype(int)

monthly_sales = data.groupby('Month')['Total'].sum()

plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_sales.index, y=monthly_sales.values, marker='o')
plt.title('Monthly Sales Variation',color='red')
plt.xlabel('Month',color='blue')
plt.ylabel('Total Sales',color='blue')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Observation : Sales only in the first three months, most sales during 1st month and least sale during 2nd month

# %% [markdown]
# #### Distribution of Customer Ratings Across Branches

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Branch', y='Rating', data=data)
plt.title('Distribution of Customer Ratings Across Branches',color='red')
plt.xlabel('Branch'c)
plt.ylabel('Rating',color='blue')
plt.show()

# %% [markdown]
# #### Quantity of Products Bought by Gender

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Gender', y='Quantity', data=data)
plt.title('Quantity of Products Bought by Gender',color='red')
plt.xlabel('Gender',color='blue')
plt.ylabel('Quantity',color='blue')
plt.show()

# %% [markdown]
# #### Gross Income by Product Type

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Product line', y='gross income', data=data)
plt.title('Gross Income by Product Type', color='red')
plt.xlabel('Product Type', color='blue')
plt.ylabel('Gross Income', color='blue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Quantity of Products Sold by Product Type

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Product line', y='Quantity', data=data)
plt.title('Quantity of Products Sold by Product Type', color='red')
plt.xlabel('Product Type', color='blue')
plt.ylabel('Quantity', color='blue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Distribution of Payment Methods

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Payment', data=data)
plt.title('Distribution of Payment Methods', color='red')
plt.xlabel('Payment Method', color='blue')
plt.ylabel('Count', color='blue')
plt.show()
